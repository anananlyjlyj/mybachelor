# %%
import matplotlib.pyplot as plt
import math
import numpy as np

def g(n):
    return 2 * math.sin(n/2) / n

x = np.arange(-30, 31, 1)
y = []
for t in x:
    y.append(g(t))
z =[]
s = np.linspace(-30, 31, 1000)
for t in s:
    z.append(g(t))
from matplotlib import collections as matcoll
lines = []
for i in range(len(x)):
    pair=[(x[i],0), (x[i], y[i])]
    lines.append(pair)

linecoll = matcoll.LineCollection(lines)
fig, ax = plt.subplots()
ax.add_collection(linecoll)
plt.grid()
plt.plot(x,y,'.')
plt.plot(s, z)
plt.show()
# Out:
# C:\Users\Yajie\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide
