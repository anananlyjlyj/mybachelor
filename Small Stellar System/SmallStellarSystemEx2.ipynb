# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy as ap

measured = 0.01192
M1 = 0.79

#def MassFunc(M1, M2, i):
#    return (M1*np.sin(i))**3/(M1+M2)**2

def inverseMassFunc(res, M1, i):
    return np.sqrt((M1*np.sin(i))**3/res) - M1

def test(res, M1, M2):
    return np.arcsin((res*(M1+M2)**2)**(1/3)/M1)

x = np.linspace(0, np.pi/2, 100)
fig, ax = plt.subplots()
values = inverseMassFunc(measured, M1, x)
ax.plot(x, values)
y_lower = 0.0
y_upper = M14.63
x_lower = test(measured, M1, 0)
x_upper = test(measured, M1, y_upper)
ax.axvline(x_lower, color='green', lw=2, alpha=0.5)
ax.axhline(y_lower, color='red', lw=2, alpha=0.5)
ax.axvline(x_upper, color='green', lw=2, alpha=0.5)
ax.axhline(y_upper, color='red', lw=2, alpha=0.5)
#ax.fill_between(values, 0, inverseMassFunc(measured, M1, 1.0), where = (x > x_lower),
#                facecolor='green', alpha=0.2)
plt.title("Mass of secondary star versus inclination")
plt.xlabel("inclination i [rad]")
plt.ylabel("Mass of secondary star [M_sun]")
print("Lower limit of inclination is about %.2f"%x_lower)
print("Upper limit of inclination is about %.2f"%x_upper)
print(inverseMassFunc(measured, M1, 0.3))
# Out:
# Lower limit of inclination is about 0.25
# Upper limit of inclination is about 0.40
# 0.24319734604888654

# %%
from sympy import *
from sympy import symbols, solve

x = symbols('x')
q = ((79*x**3/1.192)**0.5-1)
expr = x*(1+ln(1+q**(-1/3))*q**(2/3)) - 3.079*0.49/1.5


sol = solve(expr, x)


sol
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-1c79ebc810ac> in <module>
#       7
#       8
# ----> 9 sol = solve(expr, x)
#      10
#      11
#
# ~\miniconda3\lib\site-packages\sympy\solvers\solvers.py in solve(f, *symbols, **flags)
#    1172     ###########################################################################
#    1173     if bare_f:
# -> 1174         solution = _solve(f[0], *symbols, **flags)
#    1175     else:
#    1176         solution = _solve_system(f, symbols, **flags)
#
# ~\miniconda3\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1738         flags.pop('tsolve', None)  # allow tsolve to be used on next pass
#    1739         try:
# -> 1740             soln = _tsolve(f_num, symbol, **flags)
#    1741             if soln is not None:
#    1742                 result = soln
#
# ...
